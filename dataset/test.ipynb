# %%
import numpy as np
import scipy as sp
import seaborn as sns

# %%
data = np.random.randint(0, 100, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = np.random.randint(0, 100, 1000)
#
# NameError: name 'np' is not defined

# %%
np.mean(data)
np.median(data)
sp.stats.mode(data)
